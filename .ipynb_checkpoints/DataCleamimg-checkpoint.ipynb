# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
df=pd.read_csv('share.csv')
df
# Out:
#                                             County   FIPS  \
# 0                                    United States      0
# 1                           Perry County, Kentucky  21193
# 2                          Powell County, Kentucky  21197
# 3                      North Slope Borough, Alaska   2185
# 4                          Owsley County, Kentucky  21189
# ...                                            ...    ...
# 3136  Yakutat City and Borough, Alaska<sup>3</sup>   2282
# 3137             Yukon-Koyukuk Census Area, Alaska   2290
# 3138                          Zapata County, Texas  48505
# 3139                          Zavala County, Texas  48507
# 3140                  Ziebach County, South Dakota  46137
#
#      Met Objective of 45.5? (1) Age-Adjusted Death Rate  \
# 0                            No                      46
# 1                            No                   125.6
# 2                            No                   125.3
# ...

# %%
df.isnull().sum()
# Out:
# County                                          0
# FIPS                                            0
# Met Objective of 45.5? (1)                      0
# Age-Adjusted Death Rate                         0
# Lower 95% Confidence Interval for Death Rate    0
# Upper 95% Confidence Interval for Death Rate    0
# Average Deaths per Year                         0
# Recent Trend (2)                                0
# Recent 5-Year Trend (2) in Death Rates          0
# Lower 95% Confidence Interval for Trend         0
# Upper 95% Confidence Interval for Trend         0
# dtype: int64

# %%
missing_values=['*','**']
df1=pd.read_csv('share.csv',na_values=missing_values)

# %%
df1
# Out:
#                                             County   FIPS  \
# 0                                    United States      0
# 1                           Perry County, Kentucky  21193
# 2                          Powell County, Kentucky  21197
# 3                      North Slope Borough, Alaska   2185
# 4                          Owsley County, Kentucky  21189
# ...                                            ...    ...
# 3136  Yakutat City and Borough, Alaska<sup>3</sup>   2282
# 3137             Yukon-Koyukuk Census Area, Alaska   2290
# 3138                          Zapata County, Texas  48505
# 3139                          Zavala County, Texas  48507
# 3140                  Ziebach County, South Dakota  46137
#
#      Met Objective of 45.5? (1)  Age-Adjusted Death Rate  \
# 0                            No                     46.0
# 1                            No                    125.6
# 2                            No                    125.3
# ...

# %%
df1.isnull().sum()
# Out:
# County                                            0
# FIPS                                              0
# Met Objective of 45.5? (1)                      328
# Age-Adjusted Death Rate                         328
# Lower 95% Confidence Interval for Death Rate    328
# Upper 95% Confidence Interval for Death Rate    328
# Average Deaths per Year                         328
# Recent Trend (2)                                447
# Recent 5-Year Trend (2) in Death Rates          447
# Lower 95% Confidence Interval for Trend         447
# Upper 95% Confidence Interval for Trend         447
# dtype: int64

# %%
df1.dropna(thresh=3,inplace=True)

# %%
print(len(df1))
# Out:
# 2813

# %%
df1.isnull().any()
# Out:
# County                                          False
# FIPS                                            False
# Met Objective of 45.5? (1)                      False
# Age-Adjusted Death Rate                         False
# Lower 95% Confidence Interval for Death Rate    False
# Upper 95% Confidence Interval for Death Rate    False
# Average Deaths per Year                         False
# Recent Trend (2)                                 True
# Recent 5-Year Trend (2) in Death Rates           True
# Lower 95% Confidence Interval for Trend          True
# Upper 95% Confidence Interval for Trend          True
# dtype: bool

# %%
df1.isnull().sum()
# Out:
# County                                            0
# FIPS                                              0
# Met Objective of 45.5? (1)                        0
# Age-Adjusted Death Rate                           0
# Lower 95% Confidence Interval for Death Rate      0
# Upper 95% Confidence Interval for Death Rate      0
# Average Deaths per Year                           0
# Recent Trend (2)                                119
# Recent 5-Year Trend (2) in Death Rates          119
# Lower 95% Confidence Interval for Trend         119
# Upper 95% Confidence Interval for Trend         119
# dtype: int64

# %%
sns.heatmap(df1.isnull(),yticklabels=False,cbar=False)

# %%
df.replace('*', np.NaN, inplace = True)
df.replace('**', np.NaN, inplace = True)

# %%
df.isnull().sum()
# Out:
# County                                            0
# FIPS                                              0
# Met Objective of 45.5? (1)                        0
# Age-Adjusted Death Rate                           0
# Lower 95% Confidence Interval for Death Rate      0
# Upper 95% Confidence Interval for Death Rate      0
# Average Deaths per Year                           0
# Recent Trend (2)                                119
# Recent 5-Year Trend (2) in Death Rates          119
# Lower 95% Confidence Interval for Trend         119
# Upper 95% Confidence Interval for Trend         119
# dtype: int64

# %%
df.dropna(thresh=3,inplace=True)

# %%
df.fillna(0,inplace=True)

# %%
df.isnull().sum()
# Out:
# County                                          0
# FIPS                                            0
# Met Objective of 45.5? (1)                      0
# Age-Adjusted Death Rate                         0
# Lower 95% Confidence Interval for Death Rate    0
# Upper 95% Confidence Interval for Death Rate    0
# Average Deaths per Year                         0
# Recent Trend (2)                                0
# Recent 5-Year Trend (2) in Death Rates          0
# Lower 95% Confidence Interval for Trend         0
# Upper 95% Confidence Interval for Trend         0
# dtype: int64

# %%
df1['Recent 5-Year Trend (2) in Death Rates'].replace(np.NaN, df1['Recent 5-Year Trend (2) in Death Rates'].mean(), inplace = True)

# %%
df1['Recent 5-Year Trend (2) in Death Rates'].isnull().sum()
# Out:
# 0

# %%
df1.isnull().sum()
# Out:
# County                                            0
# FIPS                                              0
# Met Objective of 45.5? (1)                        0
# Age-Adjusted Death Rate                           0
# Lower 95% Confidence Interval for Death Rate      0
# Upper 95% Confidence Interval for Death Rate      0
# Average Deaths per Year                           0
# Recent Trend (2)                                119
# Recent 5-Year Trend (2) in Death Rates            0
# Lower 95% Confidence Interval for Trend         119
# Upper 95% Confidence Interval for Trend         119
# dtype: int64

# %%
df1['Recent 5-Year Trend (2) in Death Rates']
# Out:
# 0      -2.400000
# 1      -0.600000
# 2       1.700000
# 3      -1.003526
# 4       2.200000
#           ...
# 2808   -4.900000
# 2809   -1.003526
# 2810   -2.800000
# 2811   -3.200000
# 2812   -0.700000
# Name: Recent 5-Year Trend (2) in Death Rates, Length: 2813, dtype: float64

# %%
df1['Recent 5-Year Trend (2) in Death Rates'].mean()
# Out:
# -1.003526354862657

# %%
df1.shape
# Out:
# (2813, 11)

# %%
df1.dropna(how='all')
# Out:
#                            County   FIPS Met Objective of 45.5? (1)  \
# 0                   United States      0                         No
# 1          Perry County, Kentucky  21193                         No
# 2         Powell County, Kentucky  21197                         No
# 3     North Slope Borough, Alaska   2185                         No
# 4         Owsley County, Kentucky  21189                         No
# ...                           ...    ...                        ...
# 2808       Eagle County, Colorado   8037                        Yes
# 2809          Summit County, Utah  49043                        Yes
# 2810            Utah County, Utah  49049                        Yes
# 2811  McKinley County, New Mexico  35031                        Yes
# 2812           Cache County, Utah  49005                        Yes
#
#       Age-Adjusted Death Rate  Lower 95% Confidence Interval for Death Rate  \
# ...

# %%
to_drop=['County','FIPS']

# %%
df1.drop(to_drop,axis=1)
# Out:
#      Met Objective of 45.5? (1)  Age-Adjusted Death Rate  \
# 0                            No                     46.0
# 1                            No                    125.6
# 2                            No                    125.3
# 3                            No                    124.9
# 4                            No                    118.5
# ...                         ...                      ...
# 2808                        Yes                     14.9
# 2809                        Yes                     14.4
# 2810                        Yes                     12.4
# 2811                        Yes                     11.6
# 2812                        Yes                      9.2
#
#       Lower 95% Confidence Interval for Death Rate  \
# 0                                             45.9
# 1                                            108.9
# 2                                            100.2
# 3                                             73.0
# ...

# %%
df2=pd.DataFrame([[np.nan, 2, np.nan, 0], [3, 4, np.nan, 1],
...                    [np.nan, np.nan, np.nan, 5]],
...                   columns=list('ABCD'))

# %%
df2
# Out:
#      A    B   C  D
# 0  NaN  2.0 NaN  0
# 1  3.0  4.0 NaN  1
# 2  NaN  NaN NaN  5

# %%
df3=df2.dropna(subset=['D','C'],axis=0,how='all')

# %%
df3
# Out:
#      A    B   C  D
# 0  NaN  2.0 NaN  0
# 1  3.0  4.0 NaN  1
# 2  NaN  NaN NaN  5

# %%
df4=df2.dropna(axis=1, subset=[2]) #remove column  if there is any 'NaN' value in index is '1'
df4
# Out:
#    D
# 0  0
# 1  1
# 2  5

# %%
df4=df2.dropna(axis=1, subset=[2],how='all')
df4
# Out:
#    D
# 0  0
# 1  1
# 2  5
