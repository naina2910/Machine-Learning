# %%
import numpy as np
import pandas as pd
import matplotlib.pyplot as plt
import seaborn as sns

# %%
missing_values=['*','**']
df=pd.read_csv('./dataset/share.csv',na_values=missing_values)
df
# Out:
#                                             County   FIPS  \
# 0                                    United States      0
# 1                           Perry County, Kentucky  21193
# 2                          Powell County, Kentucky  21197
# 3                      North Slope Borough, Alaska   2185
# 4                          Owsley County, Kentucky  21189
# ...                                            ...    ...
# 3136  Yakutat City and Borough, Alaska<sup>3</sup>   2282
# 3137             Yukon-Koyukuk Census Area, Alaska   2290
# 3138                          Zapata County, Texas  48505
# 3139                          Zavala County, Texas  48507
# 3140                  Ziebach County, South Dakota  46137
#
#      Met Objective of 45.5? (1)  Age-Adjusted Death Rate  \
# 0                            No                     46.0
# 1                            No                    125.6
# 2                            No                    125.3
# ...

# %%
df.isnull().sum()
# Out:
# County                                            0
# FIPS                                              0
# Met Objective of 45.5? (1)                      328
# Age-Adjusted Death Rate                         328
# Lower 95% Confidence Interval for Death Rate    328
# Upper 95% Confidence Interval for Death Rate    328
# Average Deaths per Year                         328
# Recent Trend (2)                                447
# Recent 5-Year Trend (2) in Death Rates          447
# Lower 95% Confidence Interval for Trend         447
# Upper 95% Confidence Interval for Trend         447
# dtype: int64

# %%
df.dtypes
# Out:
# County                                           object
# FIPS                                              int64
# Met Objective of 45.5? (1)                       object
# Age-Adjusted Death Rate                         float64
# Lower 95% Confidence Interval for Death Rate    float64
# Upper 95% Confidence Interval for Death Rate    float64
# Average Deaths per Year                          object
# Recent Trend (2)                                 object
# Recent 5-Year Trend (2) in Death Rates          float64
# Lower 95% Confidence Interval for Trend         float64
# Upper 95% Confidence Interval for Trend         float64
# dtype: object

# %%
df['Average Deaths per Year'].fillna(0,inplace=True)

# %%
df['Average Deaths per Year'].drop([0],axis=0,inplace=True)

# %%
df.shape
# Out:
# (3141, 11)

# %%
sns.heatmap(df.isnull(),yticklabels=False,cbar=False)

# %%
df['Met Objective of 45.5? (1)'].fillna("Not Avilable",inplace=True)

# %%
df['Age-Adjusted Death Rate'].fillna(df['Age-Adjusted Death Rate'].mean(),inplace=True)

# %%
df['Lower 95% Confidence Interval for Death Rate'].fillna(df['Lower 95% Confidence Interval for Death Rate'].mean(),inplace=True)

# %%
df['Lower 95% Confidence Interval for Trend'].replace(np.NaN,df['Lower 95% Confidence Interval for Trend'].mean(),inplace=True)

# %%
df.drop('Average Deaths per Year',axis=1)
# Out:
#                                             County   FIPS  \
# 0                                    United States      0
# 1                           Perry County, Kentucky  21193
# 2                          Powell County, Kentucky  21197
# 3                      North Slope Borough, Alaska   2185
# 4                          Owsley County, Kentucky  21189
# ...                                            ...    ...
# 3136  Yakutat City and Borough, Alaska<sup>3</sup>   2282
# 3137             Yukon-Koyukuk Census Area, Alaska   2290
# 3138                          Zapata County, Texas  48505
# 3139                          Zavala County, Texas  48507
# 3140                  Ziebach County, South Dakota  46137
#
#      Met Objective of 45.5? (1)  Age-Adjusted Death Rate  \
# 0                            No                 46.00000
# 1                            No                125.60000
# 2                            No                125.30000
# ...

# %%
df.dropna(thresh=3,inplace=True)

# %%
df.isnull().sum()
# Out:
# County                                            0
# FIPS                                              0
# Met Objective of 45.5? (1)                        0
# Age-Adjusted Death Rate                           0
# Lower 95% Confidence Interval for Death Rate      0
# Upper 95% Confidence Interval for Death Rate    328
# Average Deaths per Year                           0
# Recent Trend (2)                                447
# Recent 5-Year Trend (2) in Death Rates          447
# Lower 95% Confidence Interval for Trend           0
# Upper 95% Confidence Interval for Trend         447
# dtype: int64

# %%
df.dropna(how='all',inplace=True)

# %%
df2=pd.DataFrame([[np.nan, 2, np.nan, 0], [3, 4, np.nan, 1],
...                    [np.nan, np.nan, np.nan, 5]],
...                   columns=list('ABCD'))
df2
# Out:
#      A    B   C  D
# 0  NaN  2.0 NaN  0
# 1  3.0  4.0 NaN  1
# 2  NaN  NaN NaN  5

# %%
df3=df2.dropna(subset=['D','C'],how='all')
df3
# Out:
#      A    B   C  D
# 0  NaN  2.0 NaN  0
# 1  3.0  4.0 NaN  1
# 2  NaN  NaN NaN  5

# %%
df3=df2.dropna(subset=['D','C'],how='any')
df3
# Out:
# Empty DataFrame
# Columns: [A, B, C, D]
# Index: []

# %%
df4=df2.dropna(axis=1, subset=[2]) #remove column  if there is any 'NaN' value in index is '1'
df4
# Out:
#    D
# 0  0
# 1  1
# 2  5
